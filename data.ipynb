# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Economic Data - 9 Countries (1980-2020).csv")

# %% [markdown]
# # Studying Data

# %%
df
# Out:
#     stock index                   country    year  index price  \
# 0        NASDAQ  United States of America  1980.0       168.61
# 1        NASDAQ  United States of America  1981.0       203.15
# 2        NASDAQ  United States of America  1982.0       188.98
# 3        NASDAQ  United States of America  1983.0       285.43
# 4        NASDAQ  United States of America  1984.0       248.89
# ..          ...                       ...     ...          ...
# 364      IEX 35                     Spain  2016.0      9352.10
# 365      IEX 35                     Spain  2017.0     10043.90
# 366      IEX 35                     Spain  2018.0      8539.90
# 367      IEX 35                     Spain  2019.0      9549.20
# 368      IEX 35                     Spain  2020.0      8073.70
#
#      log_indexprice  inflationrate  oil prices  exchange_rate  gdppercent  \
# 0              2.23           0.14       21.59           1.00        0.09
# ...

# %%
df.isna().sum()
# Out:
# stock index             0
# country                 0
# year                    0
# index price            52
# log_indexprice          0
# inflationrate          43
# oil prices              0
# exchange_rate           2
# gdppercent             19
# percapitaincome         1
# unemploymentrate       21
# manufacturingoutput    91
# tradebalance            4
# USTreasury              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   stock index          369 non-null    object
#  1   country              369 non-null    object
#  2   year                 369 non-null    float64
#  3   index price          317 non-null    float64
#  4   log_indexprice       369 non-null    float64
#  5   inflationrate        326 non-null    float64
#  6   oil prices           369 non-null    float64
#  7   exchange_rate        367 non-null    float64
#  8   gdppercent           350 non-null    float64
#  9   percapitaincome      368 non-null    float64
#  10  unemploymentrate     348 non-null    float64
#  11  manufacturingoutput  278 non-null    float64
#  12  tradebalance         365 non-null    float64
#  13  USTreasury           369 non-null    float64
# dtypes: float64(12), object(2)
# memory usage: 40.5+ KB

# %%
df.head(30)
# Out:
#    stock index                   country    year  index price  log_indexprice  \
# 0       NASDAQ  United States of America  1980.0       168.61            2.23
# 1       NASDAQ  United States of America  1981.0       203.15            2.31
# 2       NASDAQ  United States of America  1982.0       188.98            2.28
# 3       NASDAQ  United States of America  1983.0       285.43            2.46
# 4       NASDAQ  United States of America  1984.0       248.89            2.40
# 5       NASDAQ  United States of America  1985.0       290.25            2.46
# 6       NASDAQ  United States of America  1986.0       366.97            2.56
# 7       NASDAQ  United States of America  1987.0       402.57            2.60
# 8       NASDAQ  United States of America  1988.0       374.43            2.57
# 9       NASDAQ  United States of America  1989.0       437.80            2.64
# 10      NASDAQ  United States of America  1990.0       409.18            2.61
# ...

# %% [markdown]
# # Inflationrate and Unemploymentrate trend in united states from 1980 - 2020

# %%
co=(df["country"]=="United States of America")

# %%
df1=df.loc[co,["inflationrate","unemploymentrate","year"]].set_index("year")

# %%
df1
# Out:
#         inflationrate  unemploymentrate
# year
# 1980.0           0.14              0.07
# 1981.0           0.10              0.08
# 1982.0           0.06              0.10
# 1983.0           0.03              0.10
# 1984.0           0.04              0.08
# 1985.0           0.04              0.07
# 1986.0           0.02              0.07
# 1987.0           0.04              0.06
# 1988.0           0.04              0.05
# 1989.0           0.05              0.05
# 1990.0           0.05              0.06
# 1991.0           0.04              0.07
# 1992.0           0.03              0.07
# 1993.0           0.03              0.07
# 1994.0           0.03              0.06
# 1995.0           0.03              0.06
# 1996.0           0.03              0.05
# 1997.0           0.02              0.05
# 1998.0           0.02              0.05
# 1999.0           0.02              0.04
# 2000.0           0.03              0.04
# 2001.0           0.03              0.05
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df1.plot(kind='line')

plt.title('inflationrate and unemploymentrate trend in united states from 1980 - 2020')

plt.xlabel('Years')

plt.show()

# %% [markdown]
# ## Conclusion :
# ### Inflation rate is highest in 1980 for us and unemploymenrate is highest in 2010

# %% [markdown]
# ## percapitaincome trend in united states from 1980-2020

# %%
df2=df.loc[co,["percapitaincome","year"]].set_index("year")

# %%
df2.plot(kind='area')

plt.title('percapitaincome trend in united states from 1980-2020')

plt.xlabel('Years')

plt.show()

# %% [markdown]
# # Conclusion
# ## percapitaincome has been increasing with increase in years

# %% [markdown]
# # 0il prices in india from 1980-2020

# %%
co1=(df["country"]=="India")

# %%
df3=df.loc[co1,["oil prices","year"]].set_index("year")

# %%
df3
# Out:
#         oil prices
# year
# 1980.0       21.59
# 1981.0       31.77
# 1982.0       28.52
# 1983.0       26.19
# 1984.0       25.88
# 1985.0       24.09
# 1986.0       12.51
# 1987.0       15.40
# 1988.0       12.58
# 1989.0       15.86
# 1990.0       27.28
# 1991.0       19.50
# 1992.0       19.41
# 1993.0       14.52
# 1994.0       17.16
# 1995.0       19.03
# 1996.0       25.23
# 1997.0       18.33
# 1998.0       11.35
# 1999.0       26.10
# 2000.0       28.44
# 2001.0       19.39
# 2002.0       29.46
# 2003.0       32.13
# 2004.0       43.15
# 2005.0       59.41
# 2006.0       61.96
# 2007.0       91.69
# 2008.0       41.12
# 2009.0       74.47
# 2010.0       89.15
# 2011.0       98.56
# 2012.0       87.86
# 2013.0       97.63
# 2014.0       59.29
# 2015.0       37.19
# 2016.0       51.97
# 2017.0       57.88
# 2018.0       49.52
# 2019.0       59.88
# 2020.0       47.02

# %%
df3.plot(kind='bar',figsize=(14, 6))

plt.title('oil prices in india from 1980-2020')
plt.ylabel('prices')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# # oil prices has been maximum in the year 2011 in india

# %% [markdown]
# # unemploymentrate of all countries in the year 2020

# %%
y=(ec2["year"]==2020)

# %%
k=ec2.loc[y,["country","unemploymentrate"]].set_index('country')

# %%
k
# Out:
#                           unemploymentrate
# country
# United States of America              0.08
# United Kingdom                        0.04
# India                                 0.06
# Japan                                 0.03
# Hong Kong                             0.06
# China                                 0.05
# Germany                               0.06
# France                                0.08
# Spain                                 0.16

# %%
k.plot(kind='line',linewidth=3,linestyle='solid',marker='o',markerfacecolor='red',color='y',figsize=(14,12))
plt.title('BAR PLOT OF COUNTRIES OF UNEMPOLYMENTRATE RATE')
plt.xlabel("countries")
plt.ylabel("Unemoplymentrate")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #  conclusion : unemploymentrate has been maximum in spain and minimun in japan in the year 2020

# %%
df
# Out:
#     stock index                   country    year  index price  \
# 0        NASDAQ  United States of America  1980.0       168.61
# 1        NASDAQ  United States of America  1981.0       203.15
# 2        NASDAQ  United States of America  1982.0       188.98
# 3        NASDAQ  United States of America  1983.0       285.43
# 4        NASDAQ  United States of America  1984.0       248.89
# ..          ...                       ...     ...          ...
# 364      IEX 35                     Spain  2016.0      9352.10
# 365      IEX 35                     Spain  2017.0     10043.90
# 366      IEX 35                     Spain  2018.0      8539.90
# 367      IEX 35                     Spain  2019.0      9549.20
# 368      IEX 35                     Spain  2020.0      8073.70
#
#      log_indexprice  inflationrate  oil prices  exchange_rate  gdppercent  \
# 0              2.23           0.14       21.59           1.00        0.09
# ...

# %%
df.fillna(0)

# %%
df.isna().sum()
# Out:
# stock index             0
# country                 0
# year                    0
# index price            52
# log_indexprice          0
# inflationrate          43
# oil prices              0
# exchange_rate           2
# gdppercent             19
# percapitaincome         1
# unemploymentrate       21
# manufacturingoutput    91
# tradebalance            4
# USTreasury              0
# dtype: int64

# %% [markdown]
# # analayising percapitaincome of countries over the years

# %%
gb=df.groupby(["country"])

# %%
gb.get_group("India")
# Out:
#     stock index country    year  index price  log_indexprice  inflationrate  \
# 82     Nifty 50   India  1980.0          NaN            3.02           0.11
# 83     Nifty 50   India  1981.0          NaN            3.02           0.13
# 84     Nifty 50   India  1982.0          NaN            3.02           0.08
# 85     Nifty 50   India  1983.0          NaN            3.02           0.12
# 86     Nifty 50   India  1984.0          NaN            3.02           0.08
# 87     Nifty 50   India  1985.0          NaN            3.02           0.06
# 88     Nifty 50   India  1986.0          NaN            3.02           0.09
# 89     Nifty 50   India  1987.0          NaN            3.02           0.09
# 90     Nifty 50   India  1988.0          NaN            3.02           0.09
# 91     Nifty 50   India  1989.0          NaN            3.02           0.07
# 92     Nifty 50   India  1990.0      1048.29            3.02           0.09
# ...

# %%
pe=gb["percapitaincome"].agg(['mean','median'])

# %%
pe
# Out:
#                                   mean   median
# country
# China                      2804.195122    959.0
# France                    20830.243902  22453.0
# Germany                   25506.195122  23695.0
# Hong Kong                 24943.634146  25092.0
# India                       792.658537    443.0
# Japan                     31789.825000  35354.5
# Spain                     14199.951220  15369.0
# United Kingdom            29003.609756  28238.0
# United States of America  36879.365854  36335.0

# %%
pe.plot(kind='line',linewidth=3,linestyle='solid',marker='o',markerfacecolor='red',color=['y',"g"],figsize=(14,12))
plt.title('mean and median of percapitaincome of countries over 1980-2020')
plt.xlabel("countries")
plt.ylabel("percapitaincome")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # India percapitaincome is the  lowest compared to other countries and United States of America has the highest percapitaincome
